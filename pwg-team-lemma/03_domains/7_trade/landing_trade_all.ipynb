# %%
# %run ../../02_common_utils/raw_to_landing

# %%
recon_df = load_domain("trade")

# %%
spark.read.parquet("/Volumes/charles_schwab_retailbrokerage_dev_team_lemma/landing/pwg/Batch1/trade/").display()

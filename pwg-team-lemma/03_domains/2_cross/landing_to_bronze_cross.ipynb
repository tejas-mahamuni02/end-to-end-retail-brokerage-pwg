# %%
# Author: Virendra Dilip Tambavekar
# HRM 6217
# Task: Load 'cross' domain data from landing to bronze layer using Databricks utilities

# %%
# %run ../../02_common_utils/landing_to_bronze

# %%
recon_df=load_domain_to_bronze("cross", spark)

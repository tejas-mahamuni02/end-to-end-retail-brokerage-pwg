# %%
# Task: Data processing and analysis in Databricks notebook
# Author: Virendra Dilip Tambavekar
# HRM ID: 6217

# %%
# %run ../../02_common_utils/raw_to_landing

# %%
recon_df=load_domain("cross")
